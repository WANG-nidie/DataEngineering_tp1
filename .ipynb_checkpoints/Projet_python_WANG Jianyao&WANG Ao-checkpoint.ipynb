# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap
import webbrowser
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
from sklearn.linear_model import Ridge,RidgeCV
import sklearn
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("price.csv",encoding='ISO-8859-1', sep = ",")
df.head(10)
# Out:
#           Lng        Lat     DOM  followers  totalPrice  price  square  \
# 0  116.475489  40.019520  1464.0        106       415.0  31680  131.00
# 1  116.453917  39.881534   903.0        126       575.0  43436  132.38
# 2  116.561978  39.877145  1271.0         48      1030.0  52021  198.00
# 3  116.438010  40.076114   965.0        138       297.5  22202  134.00
# 4  116.428392  39.886229   927.0        286       392.0  48396   81.00
# 5  116.466280  39.991363   861.0         57       275.6  52000   53.00
# 6  116.482586  39.891991   851.0        167       275.0  37672   73.00
# 7  116.453917  39.881534   904.0        138       800.0  49521  161.55
# 8  116.555729  40.162058   873.0        218       134.0  27917   48.00
# 9  116.453086  39.898397   865.0        134       380.0  55883   68.00
#
#   livingRoom drawingRoom  kitchen  ...  buildingType  constructionTime  \
# 0          2           1        1  ...           1.0            2005.0
# ...

# %%
df1 = df.drop(['DOM','ladderRatio'],axis = 1,inplace = False)
df1.head(10)
# Out:
#           Lng        Lat  followers  totalPrice  price  square livingRoom  \
# 0  116.475489  40.019520        106       415.0  31680  131.00          2
# 1  116.453917  39.881534        126       575.0  43436  132.38          2
# 2  116.561978  39.877145         48      1030.0  52021  198.00          3
# 3  116.438010  40.076114        138       297.5  22202  134.00          3
# 4  116.428392  39.886229        286       392.0  48396   81.00          2
# 5  116.466280  39.991363         57       275.6  52000   53.00          1
# 6  116.482586  39.891991        167       275.0  37672   73.00          2
# 7  116.453917  39.881534        138       800.0  49521  161.55          3
# 8  116.555729  40.162058        218       134.0  27917   48.00          1
# 9  116.453086  39.898397        134       380.0  55883   68.00          1
#
#   drawingRoom  kitchen  bathRoom  buildingType  constructionTime  \
# 0           1        1       1.0           1.0            2005.0
# ...

# %%
df2 = df1.drop(df1[df1["bathRoom"]>10].index,inplace=False)
df2
# Out:
#                Lng        Lat  followers  totalPrice  price  square  \
# 0       116.475489  40.019520        106       415.0  31680  131.00
# 1       116.453917  39.881534        126       575.0  43436  132.38
# 2       116.561978  39.877145         48      1030.0  52021  198.00
# 3       116.438010  40.076114        138       297.5  22202  134.00
# 4       116.428392  39.886229        286       392.0  48396   81.00
# 5       116.466280  39.991363         57       275.6  52000   53.00
# 6       116.482586  39.891991        167       275.0  37672   73.00
# 7       116.453917  39.881534        138       800.0  49521  161.55
# 8       116.555729  40.162058        218       134.0  27917   48.00
# 9       116.453086  39.898397        134       380.0  55883   68.00
# 10      116.529489  39.890906         95       840.0  31579  266.00
# 11      116.555729  40.162058         74       126.0  26250   48.00
# 12      116.476170  39.844869         50       948.0  39832  238.00
# ...

# %%
df2.describe()
# Out:
#                  Lng            Lat      followers     totalPrice  \
# count  318821.000000  318821.000000  318821.000000  318821.000000
# mean      116.418482      39.949593      16.733082     349.051463
# std         0.112031       0.091985      34.210409     230.780445
# min       116.072514      39.627030       0.000000       0.100000
# 25%       116.344985      39.893200       0.000000     205.000000
# 50%       116.416780      39.934527       5.000000     294.000000
# 75%       116.477581      40.003018      18.000000     425.500000
# max       116.732378      40.252758    1143.000000   18130.000000
#
#                price         square        kitchen       bathRoom  \
# count  318821.000000  318821.000000  318821.000000  318819.000000
# mean    43532.956647      83.241443       0.994339       1.188122
# std     21708.395920      37.235144       0.106185       0.437544
# min         1.000000       6.900000       0.000000       0.000000
# ...

# %%
df4=df2.drop(df2[(df2["price"]<1000) | (df2["totalPrice"]<1) | (df2["square"]>750) | (df2["constructionTime"]<1930)].index,inplace=False)
df4.describe()
# Out:
#                  Lng            Lat      followers     totalPrice  \
# count  318407.000000  318407.000000  318407.000000  318407.000000
# mean      116.418475      39.949521      16.754380     349.392222
# std         0.112059       0.091970      34.227462     227.523826
# min       116.072514      39.627030       0.000000       4.000000
# 25%       116.344985      39.893200       0.000000     205.000000
# 50%       116.416780      39.934527       5.000000     294.500000
# 75%       116.477581      40.002937      18.000000     426.000000
# max       116.732378      40.252758    1143.000000    6000.000000
#
#                price         square        kitchen       bathRoom  \
# count  318407.000000  318407.000000  318407.000000  318407.000000
# mean    43587.304290      83.206589       0.994334       1.187807
# std     21665.244422      37.046940       0.106062       0.437218
# min      1000.000000       6.900000       0.000000       0.000000
# ...

# %%
print(df4.price.describe())
# Out:
# count    318407.000000
# mean      43587.304290
# std       21665.244422
# min        1000.000000
# 25%       28090.000000
# 50%       38765.000000
# 75%       53846.000000
# max      156250.000000
# Name: price, dtype: float64

# %%
plt.rcParams['font.sans-serif']=['SimHei']
sns.distplot(df4.price , color = 'lightblue',bins=20,kde=True)
plt.xlabel("price")
plt.ylabel("Density")
plt.title("Housing density histogram")
plt.show()

# %%
df4_count = df4.groupby('buildingType')['totalPrice'].count().sort_values(ascending = False).to_frame()
#df4_count = df4.groupby('district')['totalPrice'].count().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(2,1,1)
df4_count.plot(kind = 'bar',color = 'blue',alpha = 0.8,ax = ax1)
plt.xlabel('Type')
plt.ylabel('Count of house')
plt.title('The number of house in each buidingtype')
plt.show()

# %%
df4_price = df4.groupby('district')['price'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax2 = fig.add_subplot(2,1,2)
df4_price.plot(kind = 'bar',color = 'red',alpha = 0.8,ax = ax2)
plt.xlabel('District')
plt.ylabel('Ave_price per square meter')
plt.title('Average price per square meter in each district')
plt.show()

# %%
df4.groupby('constructionTime').apply(lambda x: x.sort_values('constructionTime', ascending=False , inplace = True))
df4_price = df4.groupby('constructionTime')['price'].count().to_frame()
fig = plt.figure(figsize = (20,10))
ax2 = fig.add_subplot(2,1,2)
df4_price.plot(kind = 'bar',color = 'blue',alpha = 0.8,ax = ax2)
plt.xlabel('constructionTime')
plt.ylabel('numbers')
plt.title('Number of houses by district')
plt.show()

# %%
ax3 = fig.add_subplot(1,2,2)
plt.scatter(df4['square'],df4['totalPrice'],s = 2)
plt.xlabel('Square')
plt.ylabel('TotalPrice')
plt.show()

# %%
df4.groupby('district').median().price.sort_values(ascending=False)
df4.boxplot(column='price',by='district')
plt.show()

# %%
df_district = df4['district'].value_counts()
fig = plt.figure(figsize = (15,5))
ax5 = fig.add_subplot(1,2,1)
df_district.plot(kind = 'bar',color = 'green',ax = ax5)
plt.xlabel('district')
plt.ylabel('Count')
plt.title('The count of house in each district')
plt.show()

# %%
df_district2 = df4.groupby('district')['totalPrice'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax3 = fig.add_subplot(2,1,2)
df_district2.plot(kind = 'bar',color = 'orange',ax = ax3)
plt.xlabel('district')
plt.ylabel('Mean of price')
plt.title('The price of house in each distrcit')
plt.show()

# %%
df4.groupby('subway').median().price.sort_values(ascending=False)
df4.boxplot(column='price',by='subway')
plt.show()

# %%
df_subway = df4['subway'].value_counts()
fig = plt.figure(figsize = (15,5))
ax5 = fig.add_subplot(1,2,1)
df_subway.plot(kind = 'bar',color = 'green',ax = ax5)
plt.xlabel('subway')
plt.ylabel('Count')
plt.title('The count of house with and without subway')
plt.show()

# %%
df_subway2 = df4.groupby('subway')['totalPrice'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax3 = fig.add_subplot(2,1,2)
df_subway2.plot(kind = 'bar',color = 'orange',ax = ax3)
plt.xlabel('subway')
plt.ylabel('Mean of price')
plt.title('The price of house with and without subway')
plt.show()

# %%
df4.groupby('buildingType').median().price.sort_values(ascending=False)
df4.boxplot(column='price',by='buildingType')
plt.show()

# %%
df_buildingType = df4['buildingType'].value_counts()
fig = plt.figure(figsize = (15,5))
ax5 = fig.add_subplot(1,2,1)
df_buildingType.plot(kind = 'bar',color = 'green',ax = ax5)
plt.xlabel('buildingType')
plt.ylabel('Count')
plt.title('The count of house with different buildingtype')
plt.show()

# %%
df_buildingType2 = df4.groupby('buildingType')['totalPrice'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax3 = fig.add_subplot(2,1,2)
df_buildingType2.plot(kind = 'bar',color = 'orange',ax = ax3)
plt.xlabel('buildingType')
plt.ylabel('Mean of price')
plt.title('The price of house with different buildingtype')
plt.show()

# %%
df4.groupby('elevator').median().price.sort_values(ascending=False)
df4.boxplot(column='price',by='elevator')
plt.show()

# %%
df_elevator = df4['elevator'].value_counts()
fig = plt.figure(figsize = (15,5))
ax5 = fig.add_subplot(1,2,1)
df_elevator.plot(kind = 'bar',color = 'green',ax = ax5)
plt.xlabel('elevator')
plt.ylabel('Count')
plt.title('The count of house with and without elevators')
plt.show()

# %%
df_elevator2 = df4.groupby('elevator')['totalPrice'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax3 = fig.add_subplot(2,1,2)
df_elevator2.plot(kind = 'bar',color = 'orange',ax = ax3)
plt.xlabel('elevator')
plt.ylabel('Mean of price')
plt.title('The price of house with and without elevators')
plt.show()

# %%
df4.plot.scatter(x='price',y="square")
plt.show()

# %%
df4.groupby('renovationCondition').median().price.sort_values(ascending=False)
df4.boxplot(column='price',by='renovationCondition')
plt.show()

# %%
df_condition = df4.groupby('renovationCondition')['totalPrice'].median().sort_values(ascending = False).to_frame()
fig = plt.figure(figsize = (20,10))
ax2 = fig.add_subplot(2,1,2)
df_condition.plot(kind = 'bar',color = 'orange',ax = ax2)
plt.xlabel('RenovationCondition')
plt.ylabel('Mean of price')
plt.title('Compare between renovationCondition and mean of price')
plt.show()

# %%
df_condition2 = df4['renovationCondition'].value_counts()
fig = plt.figure(figsize = (10,8))
ax1 = fig.add_subplot(2,1,2)
df_condition2.plot(kind = 'bar',color = 'green',ax = ax1)
plt.xlabel('RenovationCondition')
plt.ylabel('Count')
plt.title('The count of different renovationCondition')
plt.show()

# %%
print(df4.groupby(['district','subway']).median().price.sort_values(ascending=False).unstack())
df4.boxplot(column='price',by=['district','subway'],figsize = (26,13))
plt.show()
# Out:
# subway        0.0      1.0
# district
# 1         54019.5  56941.0
# 2         34179.0  36234.5
# 3         29947.0  28339.0
# 4         26488.5  27308.0
# 5         24302.0  30618.0
# 6         26251.5  28592.0
# 7         36504.5  41570.0
# 8         46381.5  53334.0
# 9         32061.0  32560.0
# 10        61309.0  62973.0
# 11        23243.0  23737.5
# 12        23390.0  39985.0
# 13        20737.0  23915.0

# %%
print(df4.groupby(['elevator','subway']).median().price.sort_values(ascending=False).unstack())
df4.boxplot(column='price',by=['elevator','subway'],figsize = (12,6))
plt.show()
# Out:
# subway        0.0      1.0
# elevator
# 0.0       29271.0  43255.5
# 1.0       36178.0  42133.0

# %%
print(df4.groupby(['district','elevator']).median().price.sort_values(ascending=False).unstack())
df4.boxplot(column='price',by=['district','elevator'],figsize = (26,13))
plt.show()
# Out:
# elevator      0.0      1.0
# district
# 1         59115.0  55185.0
# 2         34843.5  35869.0
# 3         28424.0  29257.0
# 4         24355.0  31963.0
# 5         23082.0  27934.0
# 6         26563.0  28962.5
# 7         39209.0  40627.0
# 8         52890.0  49349.0
# 9         30974.0  34043.5
# 10        65135.0  59958.0
# 11        22178.0  24457.0
# 12        22335.0  25700.0
# 13        20623.0  23703.0

# %%
print(df4.groupby(['district','elevator','subway']).median().price.sort_values(ascending=False).unstack())
df4.boxplot(column='price',by=['district','elevator','subway'],figsize = (20,10))
plt.xticks(rotation=90)
plt.show()
# Out:
# subway                 0.0      1.0
# district elevator
# 1        0.0       50303.5  59777.0
#          1.0       56690.5  55105.0
# 2        0.0       31679.0  36344.0
#          1.0       35198.5  36186.0
# 3        0.0       28311.0  29315.0
#          1.0       31295.0  28259.0
# 4        0.0       23831.5  25121.0
#          1.0       31373.0  32768.0
# 5        0.0       21458.0  25571.0
#          1.0       25074.0  31641.0
# 6        0.0       25514.0  28053.5
#          1.0       28510.0  29479.0
# 7        0.0       33402.0  41791.0
#          1.0       38291.0  41482.0
# 8        0.0       46954.0  55917.0
#          1.0       46008.5  51377.0
# 9        0.0       30729.5  31782.5
#          1.0       34228.0  33451.0
# 10       0.0       65945.0  64859.5
#          1.0       54737.5  61170.0
# 11       0.0       21959.0  22988.0
#          1.0       25022.5  24056.0
# 12       0.0       22335.0      NaN
#          1.0       25699.0  39985.0
# ...

# %%
R =[]
for i in df4['renovationCondition']:
    if i == 4:
        R.append(10)
    elif i == 3:
        R.append(8)
    elif i == 2:
        R.append(6)
    else :
        R.append(4)
        
E = []
for i in df4['elevator']:
    if i == 1.0 :
        E.append(30)
    else :
        E.append(5)

fig = plt.figure(figsize = (10,10))
plt.scatter(df4['constructionTime'],df4['totalPrice'],
           s = E,
           cmap = 'Reds',
           c = R,
           alpha = 0.8)
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Year-Price-Elevator-RenovationCondition Dimensional figure')
plt.show()

# %%
df5=df4.dropna()
lng = np.array(df5["Lng"][0:len(df5)]) 
lat = np.array(df5["Lat"][0:len(df5)])
pri = np.array(df5["totalPrice"][0:len(df5)],dtype=float)
data1 = [[lat[i],lng[i],pri[i]] for i in range(len(df5))] 
map_osm = folium.Map(location=[40,116],zoom_start=10)
HeatMap(data1,radius=10,gradient={.4:'green',.65:'yellow',.95:'red'}).add_to(map_osm) 
file_path = r"C:\Users\dell\Desktop\python\heatmap.html" 
map_osm.save(file_path) 
webbrowser.open(file_path)
# Out:
# True

# %%
f,ax=plt.subplots(figsize=(15,12))
sns.heatmap(df5.corr(),vmax=0.8,square=True)
# Out:
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df6=df5.drop(columns=['totalPrice','Lat','Lng','communityAverage','followers'],axis=1)

f,ax=plt.subplots(figsize=(24,32))
sns.heatmap(df6.corr(),vmax=0.8,square=True)
k=19
cols=df6.corr().nlargest(k,'price')['price'].index
cm=np.corrcoef(df6[cols].values.T)
sns.set(font_scale=1.25)
sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size':19},yticklabels=cols.values,xticklabels=cols.values)

# %%
train_df = pd.read_csv("price_train.csv",encoding='ISO-8859-1',sep = ',')
test_df = pd.read_csv("price_test.csv",encoding='ISO-8859-1', sep=',')
train_df1 = train_df.pop("price")
test_df1 = test_df.pop("price")


train_df.head(10)
# Out:
#    square livingRoom drawingRoom  kitchen  bathRoom  buildingType  \
# 0  131.00          2           1        1       1.0           1.0
# 1  132.38          2           2        1       2.0           1.0
# 2  198.00          3           2        1       3.0           4.0
# 3  134.00          3           1        1       1.0           1.0
# 4   81.00          2           1        1       1.0           4.0
# 5   53.00          1           0        1       1.0           4.0
# 6   73.00          2           1        1       1.0           4.0
# 7  161.55          3           2        1       2.0           1.0
# 8   48.00          1           0        1       1.0           3.0
# 9   68.00          1           0        0       0.0           1.0
#
#    constructionTime  renovationCondition  buildingStructure  elevator  \
# 0            2005.0                    3                  6       1.0
# 1            2004.0                    4                  6       1.0
# ...

# %%
train_df.shape
# Out:
# (199998, 13)

# %%
test_df.shape
# Out:
# (118852, 13)

# %%
train_df1.hist()

# %%
y_train = np.log1p(train_df1)
sns.distplot(y_train)

# %%
y_train
# Out:
# 0         10.363472
# 1         10.679067
# 2         10.859422
# 3         10.007983
# 4         10.787193
# 5         10.859018
# 6         10.536699
# 7         10.810172
# 8         10.237027
# 9         10.931033
# 10        10.360279
# 11        10.175459
# 12        10.592451
# 13        11.426398
# 14        10.479230
# 15        11.012182
# 16        10.574287
# 17        10.403717
# 18        10.315266
# 19        10.421626
# 20        11.054518
# 21        10.275086
# 22        11.375696
# 23        11.225243
# 24        10.871782
# 25        10.502818
# 26        10.315266
# 27        10.606238
# 28        11.354715
# 29        10.580988
#             ...
# 199968    11.017432
# 199969    10.593906
# 199970    10.932821
# 199971    10.864331
# 199972    10.804908
# 199973    10.556802
# 199974    10.949788
# 199975    10.959297
# 199976    10.756306
# 199977    11.461643
# 199978    10.692763
# 199979    10.845037
# 199980    10.952104
# 199981    11.004613
# ...

# %%
ml=pd.concat((train_df,test_df),axis=0)
ml.shape
# Out:
# (318850, 13)

# %%
ml['buildingType'] = ml['buildingType'].astype(str)
ml['renovationCondition'] = ml['renovationCondition'].astype(str)
ml['buildingStructure'] = ml['buildingStructure'].astype(str)

# %%
mean_cols = ml.mean()
ml.fillna(mean_cols,inplace= True)

# %%
ml.isnull().sum().sort_values(ascending=False).head()
# Out:
# district             0
# subway               0
# fiveYearsProperty    0
# elevator             0
# buildingStructure    0
# dtype: int64

# %%
dummied_data = pd.get_dummies(ml)
dummied_data
# Out:
#         square  kitchen  bathRoom  constructionTime  elevator  \
# 0       131.00        1       1.0        2005.00000       1.0
# 1       132.38        1       2.0        2004.00000       1.0
# 2       198.00        1       3.0        2005.00000       1.0
# 3       134.00        1       1.0        2008.00000       1.0
# 4        81.00        1       1.0        1960.00000       0.0
# 5        53.00        1       1.0        2005.00000       1.0
# 6        73.00        1       1.0        1997.00000       0.0
# 7       161.55        1       2.0        2004.00000       1.0
# 8        48.00        1       1.0        2009.00000       0.0
# 9        68.00        0       0.0        2009.00000       1.0
# 10      266.00        1       3.0        2006.00000       0.0
# 11       48.00        1       1.0        2009.00000       0.0
# 12      238.00        1       4.0        2004.00000       0.0
# 13       97.70        1       1.0        1991.00000       0.0
# ...

# %%
dummied_data.isnull().sum().sort_values(ascending=False).head()
# Out:
# buildingStructure_6    0
# livingRoom_1           0
# livingRoom_3           0
# livingRoom_4           0
# livingRoom_5           0
# dtype: int64

# %%
numerical_cols = ml.columns[ml.dtypes != 'object'] 
num_cols_mean = dummied_data.loc[:, numerical_cols].mean()
num_cols_std = dummied_data.loc[:, numerical_cols].std()
dummied_data.loc[:, numerical_cols] = (dummied_data.loc[:, numerical_cols] - num_cols_mean) / num_cols_std

# %%
dummied_data.shape
# Out:
# (318850, 82)

# %%
X_train = dummied_data.iloc[0:199998,:].values
X_test = dummied_data.iloc[199998:,:].values

# %%
X_train.shape
# Out:
# (199998, 82)

# %%
X_test.shape
# Out:
# (118852, 82)

# %%
alphas = np.logspace(-3,2,50)
alphas
# Out:
# array([1.00000000e-03, 1.26485522e-03, 1.59985872e-03, 2.02358965e-03,
#        2.55954792e-03, 3.23745754e-03, 4.09491506e-03, 5.17947468e-03,
#        6.55128557e-03, 8.28642773e-03, 1.04811313e-02, 1.32571137e-02,
#        1.67683294e-02, 2.12095089e-02, 2.68269580e-02, 3.39322177e-02,
#        4.29193426e-02, 5.42867544e-02, 6.86648845e-02, 8.68511374e-02,
#        1.09854114e-01, 1.38949549e-01, 1.75751062e-01, 2.22299648e-01,
#        2.81176870e-01, 3.55648031e-01, 4.49843267e-01, 5.68986603e-01,
#        7.19685673e-01, 9.10298178e-01, 1.15139540e+00, 1.45634848e+00,
#        1.84206997e+00, 2.32995181e+00, 2.94705170e+00, 3.72759372e+00,
#        4.71486636e+00, 5.96362332e+00, 7.54312006e+00, 9.54095476e+00,
#        1.20679264e+01, 1.52641797e+01, 1.93069773e+01, 2.44205309e+01,
#        3.08884360e+01, 3.90693994e+01, 4.94171336e+01, 6.25055193e+01,
#        7.90604321e+01, 1.00000000e+02])

# %%
test_scores = []
for alpha in alphas:
    clf = linear_model.Ridge(alpha)
    test_score = np.sqrt(-cross_val_score(model,X_train, y_train, cv=10, scoring='neg_mean_squared_error'))
    test_scores.append(np.mean(test_score))
plt.plot(alphas, test_scores)
# Out:
# [20:00:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:02:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:05:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:08:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:10:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:13:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#ridge = Ridge(alpha = 15)
rf = RandomForestRegressor(n_estimators=350,max_features = "auto")
#ridge.fit(X_train , y_train)
rf.fit(X_train , y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=350,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
ridge_predict = ridge.predict(X_test)
rf_predict = rf.predict(X_test)
test_score = rf.score(X_train , y_train)
test_score
# Out:
# 0.8949973022948048

# %%
y_ridge = np.expm1(ridge_predict)
y_rf = np.expm1(rf_predict)
y_ridge[0:30]
# Out:
# array([46417.4109276 , 41505.45831355, 42260.2487733 , 44272.46993941,
#        41424.49220682, 40127.64235516, 41388.08815491, 40333.3971418 ,
#        35346.54922919, 31351.636734  , 41036.45090807, 34954.13524622,
#        37315.51677718, 40255.57242061, 36765.62675144, 30407.41022984,
#        45087.49706305, 28060.33938122, 45760.77904692, 46724.78331906,
#        40279.02740028, 42247.35256766, 41802.68036226, 41230.86945246,
#        82756.0240747 , 41420.63052563, 45716.63804788, 45696.13648633,
#        30105.15618774, 33078.10543245])

# %%
y_rf
y_final = (y_ridge+y_rf)/2
y_final[0:20]
# Out:
# array([68851.23043115, 75443.85605857, 72554.82173457, 41309.2206809 ,
#        72327.47555203, 67880.76846291, 71663.29981539, 70935.06141569,
#        61334.19991951, 48006.35778444, 73482.996701  , 37048.59624548,
#        47039.68152152, 64462.04538864, 60613.74642535, 33788.57913768,
#        61100.92555741, 30742.74617624, 68542.02836466, 70666.08668444])

# %%
submitted_data = pd.DataFrame(data= {'Id' : test_df.index, 'SalePrice': y_final})
submitted_data.to_csv(r"C:\Users\dell\Desktop\python\submission.csv", encoding='ISO-8859-1',index = False)
